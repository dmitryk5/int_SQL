# %% [markdown]
# <a href="https://colab.research.google.com/github/dmitryk5/int_SQL/blob/main/Statistical_Aggregations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Libraries & Database

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# If running in Google Colab, install PostgreSQL and restore the database
if 'google.colab' in sys.modules:
    # Update package installer
    # !sudo apt-get update -qq > /dev/null 2>&1

    # Install PostgreSQL
    # !sudo apt-get install postgresql -qq > /dev/null 2>&1

    # Start PostgreSQL service (suppress output)
    # !sudo service postgresql start > /dev/null 2>&1

    # Set password for the 'postgres' user to avoid authentication errors (suppress output)
    # !sudo -u postgres psql -c "ALTER USER postgres WITH PASSWORD 'password';" > /dev/null 2>&1

    # Create the 'colab_db' database (suppress output)
    # !sudo -u postgres psql -c "CREATE DATABASE contoso_100k;" > /dev/null 2>&1

    # Download the PostgreSQL .sql dump
    # !wget -q -O contoso_100k.sql https://github.com/lukebarousse/Int_SQL_Data_Analytics_Course/releases/download/v.0.0.0/contoso_100k.sql

    # Restore the dump file into the PostgreSQL database (suppress output)
    # !sudo -u postgres psql contoso_100k < contoso_100k.sql > /dev/null 2>&1

    # Shift libraries from ipython-sql to jupysql
    # !pip uninstall -y ipython-sql > /dev/null 2>&1
    # !pip install jupysql > /dev/null 2>&1

# Load the sql extension for SQL magic
# %load_ext sql

# Connect to the PostgreSQL database
# %sql postgresql://postgres:password@localhost:5432/contoso_100k

# Enable automatic conversion of SQL results to pandas DataFrames
# %config SqlMagic.autopandas = True

# Disable named parameters for SQL magic
# %config SqlMagic.named_parameters = "disabled"

# Display pandas number to two decimal places
pd.options.display.float_format = '{:.2f}'.format
# Out:
# Connecting to 'postgresql://postgres:***@localhost:5432/contoso_100k'

# %% [markdown]
# ## Total Net Revenue by Category

# %%
# %%sql
#
# SELECT
#     p.categoryname AS category_name,
#     AVG(CASE WHEN s.orderdate BETWEEN '2022-01-01' AND '2022-12-31' THEN s.quantity * s.netprice * s.exchangerate END) AS avg_net_revenue_2022,
#     AVG(CASE WHEN s.orderdate BETWEEN '2023-01-01' AND '2023-12-31' THEN s.quantity * s.netprice * s.exchangerate END) AS avg_net_revenue_2023
# FROM
#     sales s
# LEFT JOIN
#     product p ON s.productkey = p.productkey
# WHERE
#     s.orderdate BETWEEN '2022-01-01' AND '2023-12-31'
# GROUP BY
#     p.categoryname
# ORDER BY
#     p.categoryname;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 8 rows affected.
#                    category_name  avg_net_revenue_2022  avg_net_revenue_2023
# 0                          Audio                392.30                425.38
# 1        Cameras and camcorders                1210.02               1210.96
# 2                    Cell phones                722.20                623.28
# 3                      Computers               1565.62               1292.39
# 4                 Games and Toys                 81.29                 80.83
# 5                Home Appliances               1755.36               1886.55
# 6  Music, Movies and Audio Books                386.61                334.58
# 7                   TV and Video               1535.61               1687.90
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['avg_net_revenue_2022'].plot(kind='hist', bins=20, title='avg_net_revenue_2022')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['avg_net_revenue_2023'].plot(kind='hist', bins=20, title='avg_net_revenue_2023')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('category_name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='avg_net_revenue_2022', y='avg_net_revenue_2023', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4['avg_net_revenue_2022'].plot(kind='line', figsize=(8, 4), title='avg_net_revenue_2022')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5['avg_net_revenue_2023'].plot(kind='line', figsize=(8, 4), title='avg_net_revenue_2023')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_6['category_name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_6, x='avg_net_revenue_2022', y='category_name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_7['category_name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_7, x='avg_net_revenue_2023', y='category_name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ## Max/Min Net Revenue by Category

# %%
# %%sql
#
# SELECT
#     p.categoryname AS category_name,
#     AVG(CASE WHEN s.orderdate BETWEEN '2022-01-01' AND '2022-12-31' THEN s.quantity * s.netprice * s.exchangerate END) AS avg_net_revenue_2022,
#     MIN(CASE WHEN s.orderdate BETWEEN '2022-01-01' AND '2022-12-31' THEN s.quantity * s.netprice * s.exchangerate END) AS min_net_revenue_2022,
#     MAX(CASE WHEN s.orderdate BETWEEN '2022-01-01' AND '2022-12-31' THEN s.quantity * s.netprice * s.exchangerate END) AS max_net_revenue_2022,
#     AVG(CASE WHEN s.orderdate BETWEEN '2023-01-01' AND '2023-12-31' THEN s.quantity * s.netprice * s.exchangerate END) AS avg_net_revenue_2023,
#     MIN(CASE WHEN s.orderdate BETWEEN '2023-01-01' AND '2023-12-31' THEN s.quantity * s.netprice * s.exchangerate END) AS min_net_revenue_2023,
#     MAX(CASE WHEN s.orderdate BETWEEN '2023-01-01' AND '2023-12-31' THEN s.quantity * s.netprice * s.exchangerate END) AS max_net_revenue_2023
# FROM
#     sales s
# LEFT JOIN
#     product p ON s.productkey = p.productkey
# WHERE
#     s.orderdate BETWEEN '2022-01-01' AND '2023-12-31'
# GROUP BY
#     p.categoryname
# ORDER BY
#     p.categoryname;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 8 rows affected.
#                    category_name  avg_net_revenue_2022  min_net_revenue_2022  \
# 0                          Audio                392.30                  9.31
# 1        Cameras and camcorders                1210.02                  6.74
# 2                    Cell phones                722.20                  2.53
# 3                      Computers               1565.62                  0.83
# 4                 Games and Toys                 81.29                  2.83
# 5                Home Appliances               1755.36                  4.04
# 6  Music, Movies and Audio Books                386.61                  7.29
# 7                   TV and Video               1535.61                 41.30
#
#    max_net_revenue_2022  avg_net_revenue_2023  min_net_revenue_2023  \
# 0               3473.36                425.38                 10.85
# 1              15008.39               1210.96                  5.98
# 2               7692.37                623.28                  2.28
# 3              38082.66               1292.39                  0.75
# 4               5202.01                 80.83                  3.49
# 5              31654.55               1886.55                  4.54
# 6               5415.19                334.58                  6.91
# 7              30259.41               1687.90                 42.30
#
#    max_net_revenue_2023
# 0               2730.87
# 1              13572.00
# 2               8912.22
# 3              27611.60
# 4               3357.30
# 5              32915.59
# 6               3804.91
# 7              27503.12

# %% [markdown]
# # Median Net Revenue by Category

# %%
# %%sql
#
# SELECT
#    PERCENTILE_CONT(.50) WITHIN GROUP (ORDER BY netprice) AS median_price
# FROM
#   sales
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 1 rows affected.
#    median_price
# 0        191.95

# %%
# %%sql
#
# SELECT
#     p.categoryname AS category_name,
#     PERCENTILE_CONT(.5) WITHIN GROUP (ORDER BY (CASE
#       WHEN s.orderdate BETWEEN '2022-01-01' AND '2022-12-31' THEN (s.quantity * s.netprice * s.exchangerate) END)) AS y2022_median_sales,
#     PERCENTILE_CONT(.5) WITHIN GROUP (ORDER BY (CASE
#       WHEN s.orderdate BETWEEN '2023-01-01' AND '2023-12-31' THEN (s.quantity * s.netprice * s.exchangerate) END)) AS y2023_median_sales
# FROM
#     sales s
# LEFT JOIN
#     product p ON s.productkey = p.productkey
# WHERE
#     s.orderdate BETWEEN '2022-01-01' AND '2023-12-31'
# GROUP BY
#     p.categoryname
# ORDER BY
#     p.categoryname;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 8 rows affected.
#                    category_name  y2022_median_sales  y2023_median_sales
# 0                          Audio              257.21              266.59
# 1        Cameras and camcorders               651.46              672.60
# 2                    Cell phones              418.60              375.88
# 3                      Computers              809.70              657.18
# 4                 Games and Toys               33.78               32.62
# 5                Home Appliances              791.00              825.25
# 6  Music, Movies and Audio Books              186.58              159.63
# 7                   TV and Video              730.46              790.79
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['y2022_median_sales'].plot(kind='hist', bins=20, title='y2022_median_sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['y2023_median_sales'].plot(kind='hist', bins=20, title='y2023_median_sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_10.groupby('category_name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11.plot(kind='scatter', x='y2022_median_sales', y='y2023_median_sales', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['y2022_median_sales'].plot(kind='line', figsize=(8, 4), title='y2022_median_sales')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['y2023_median_sales'].plot(kind='line', figsize=(8, 4), title='y2023_median_sales')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['category_name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='y2022_median_sales', y='category_name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['category_name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='y2023_median_sales', y='category_name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ## Categorize
#
# *   "High Value Order" if `quantity >= 2` and `netprice >= 50`
# *   "Standard Order" otherwise

# %%
# %%sql
#
# SELECT
#   orderdate,
#   quantity,
#   netprice
# FROM
#   sales
# LIMIT 10
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 10 rows affected.
#     orderdate  quantity  netprice
# 0  2015-01-01         1     98.97
# 1  2015-01-01         1    659.78
# 2  2015-01-01         2     54.38
# 3  2015-01-01         4    286.69
# 4  2015-01-01         7    135.75
# 5  2015-01-01         3    434.30
# 6  2015-01-01         1     58.73
# 7  2015-01-01         3     74.99
# 8  2015-01-01         2    113.57
# 9  2015-01-01         1    499.45
